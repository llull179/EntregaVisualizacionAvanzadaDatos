# %% [markdown]
# # Práctica 1 - Dilema del Prisionero Iterado
#
# ## Introducción
#
# La *Teoría de Juegos* es una rama de las matemáticas que estudia la interacción entre individuos racionales. Para su estudio, es habitual que se utilicen *juegos* o *dilemas* en los que los agentes implicados puedan escoger entre varias *acciones*. El resultado del juego dependerá de la acción propia y las de los oponentes. Un ejemplo muy conocido es el juego de *piedra, papel y tijera*.
#
# Probablemente el *juego* o *dilema* más estudiado dentro de la Teoría de Juegos es el [**Dilema del Prisionero**](https://en.wikipedia.org/wiki/Prisoner%27s_dilemma). En este dilema, los jugadores tienen dos opciones: cooperar (C) o desertar (D). A la siguiente matriz se la conoce como *matriz de pagos* (*payoff matrix*), y es una forma compacta de representar un juego: por filas se representa a un jugador, y por columnas al otro.
#
# <center>
#
# |      |  C    |  D    |
# |------|-------|-------|
# |   **C**  | 2, 2  | -1, 3 |
# |   **D**  | 3, -1 |  0, 0 |
#
# </center>
#
# Las celdas interiores de la matriz establecen los pagos que se lleva cada jugador. El primer número de la tupla es el pago al jugador *fila*, y el segundo número el pago al jugador *columna*. Por ejemplo, si el jugador *fila* deserta (D) y el jugador *columna* coopera (C), el primero se llevará 3 puntos y el segundo *-1*. En verdad, los valores de la tabla no son *puntos*, es una medida sin dimensiones cuya única función es permitirnos comparar resultados. De hecho, no existe un *único* dilema del prisionero: se pueden modificar los valores anteriores libremente, siempre que se mantengan las relaciones ordinales entre ellos.
#
# Para juegos simétricos como el dilema del prisionero, suele ser más conveniente utilizar la *matriz de pagos simplificada*
#
# <center>
#
# $$
# \begin{pmatrix}
# 2 & -1 \\
# 3 & 0
# \end{pmatrix}
# $$
#
# </center>
#
#
# No olvides que los jugadores del dilema del prisionero son jugadores racionales. Además, **el objetivo no es *ganar* al rival, sino maximizar el beneficio personal**. Estas dos premisas son las hipótesis sobre las que se sustenta todo lo que viene a continuación.
#
# Cuando se juega al dilema del prisionero una única vez, la estrategia óptima es la de desertar (ejercicio: reflexiona sobre el por qué). Sin embargo, la complejidad surge cuando los jugadores se enfrentan repetidamente con el mismo oponente, ya que sus acciones actuales influirán en su reputación a largo plazo. Esta variante se conoce como el **Dilema del Prisionero Iterado** y ha sido objeto de profundo estudio en la literatura científica. A pesar de que John von Neumann fue el primero en plantear este dilema, Robert Axelrod ha destacado como uno de los científicos más influyentes en su análisis.
#
# Axelrod planteó varios "campeonatos computacionales", en los que los participantes debían proponer una estrategia para jugar al DPI. Luego Axelrod enfrentó todas las estrategias y vio cuáles eran las que mejor funcionaban. Una *estrategia* para jugar al DPI es un conjunto de instrucciones inequívocas que, a partir del histórico de movimientos de ambos jugadores, dice cuál debe ser el siguiente movimiento. Por ejemplo, lo siguiente sería una estrategia: "comienzo cooperando, luego deserto dos veces, y a partir de la cuarta ronda coopero siempre". Algunas de estas estrategias se han hecho famosas por ser exitosas o por aparece con frecuencia en la literatura.
#
# Axelrod comenzó estudiando torneos *normales* (llamados *de enfrentamiento directo*), donde cada participante (estrategia) es enfrentado contra cada uno de los demás, sumando los resultados obtenidos en cada interacción, y estableciendo un ranking al final del campeonato. También estudió los llamados *torneos evolutivos*. En ellos cada estrategia parte con un número de individuos representantes que juegan siempre esa estrategia. Tras enfrentar todos los individuos contra todos, se elimina de la población los que peor resultado han obtenido, sustituyéndolos por los más exitosos. Este proceso se repite varias veces, dando lugar (en muchos casos) a que una estrategia coloniza a la población completa: se encuentra la estrategia óptima. En escenarios más avanzados, se permite también la evolución de las estrategias a lo largo de las generaciones, mediante mecanismos de mutación y cruce (selección natural).
#
# Las metaheurísticas son técnicas de optimización confeccionadas para casos particulares, complejos y dinámicos. El DPI evolutivo es ejemplo tangible de esta técnica. En este problema, múltiples soluciones compiten y evolucionan hacia la optimización de un objetivo dado.

# %% [markdown]
# ## Descripción de la práctica
#
# **¡Importante!** Comienza jugando al juego de Nicky Case llamado *The evolution of trust* (~30min). Es un buen resumen de los conceptos previos que necesitas saber sobre el DPI antes de comenzar la práctica:
# <center>
#
# [<img src="https://ncase.me/img/trust.png" alt="The evolution of trust: https://ncase.me/trust/" width="400">](https://ncase.me/trust/)
#
# https://ncase.me/trust/
# </center>
# Unas aclaraciones sobre el juego: en ocasiones, el autor utiliza una nomenclatura que no es habitual en la literatura del DPI. Por evitar confusiones:
#
#  - Las acciones posibles en el dilema las llamaremos Cooperar (*Cooperate*) y Desertar (*Defect*), y no *cheat*.
#  - La estrategia que repite el último movimiento del rival se conoce ampliamente como *Tit-For-Tat*, y no *Copycat*.
#
# La práctica tiene dos partes:
#  - **Parte 1**: Montar la estructura computacional que permita simular torneos del DPI.
#  - **Parte 2**: Diseñar una estrategia, que se enfrentará a las de tus compañeros en un torneo de tres fases descrito a continuación.

# %% [markdown]
# ## Parte 1: Sofware para el estudio del DPI
#
# El primer objetivo es crear un sofware que permita simular torneos del DPI. En concreto, el software debe cumplir los siguientes requisitos:

# %% [markdown]
#  - Para el torneo de enfrentamiento directo, las entradas al programa deben ser:
#    - ```all_players```: lista o tupla de jugadores que van a participar en el campeonato (con información sobre sus estrategias).
#    - ```dilemma```: objeto para definir el dilema del prisionero jugado (en particular, deberá contener la información de la correspondiente matriz de pagos, que es la mostrada arriba).
#    - ```n_rounds```: número de rondas por cada enfrentamiento.
#    - ```error```: probabilidad de error por jugada.
#    - ```repetitions```: el número de veces que una estrategia va a enfrentarse a otra.
#  - La salida debe ser la información (visual) sobre el resultado del campeonato.
#  - Además, el programa deberá contener al menos las 5 estrategias básicas descritas en el juego de Nicky Case. Igualmente, deberá permitir añadir nuevas estrategias de forma sencilla.
#
# Consulta la sección sobre el *módulo evolutivo* para ver las particularidades de esa parte.
#
# A continuación se propone una **plantilla de desarrollo** con los módulos/clases que se recomienda implementar para resolver este problema. No es obligatorio seguir esta estructura. Por otro lado, puede ser recomendable organizar el código en un proyecto local en lugar de en *Jupyter* o *Colab*. Si quieres hacerlo, la estructura del proyecto recomendada es la siguiente:
#
# ```
#  DPI/
#    ├── dpi/
#    │   ├── __init__.py
#    │   ├── dilemma.py  # implementa la lógica del DP jugado, acciones posibles, matriz de pagos, etc
#    │   ├── player.py  # implementa la definición de "Jugador" y en particular, la estrategia
#    │   ├── game.py  # implementa la dinámica de un juego cara a cara entre dos jugadores
#    │   ├── tournament.py  # implementa la dinámica del torneo general
#    │   └── evolution.py  # implementa la dinámica del torneo evolutivo
#    ├── main.py # main del proyecto - si quieres, usa varios 'mains' para testear los distintos módulos
#    └──...
# ```

# %% [markdown]
# ### Plantilla de desarrollo
#
# Se incluye a continuación una plantilla con los módulos/clases que se recomienda implementar, junto con variables y métodos necesarios. El objetivo es facilitar la tarea de diseñar el código. No es obligatorio seguir esta estructura, pero a falta de mejores ideas, puede ser un buen punto de partida.
#
# Para facilitar la tarea de identificar qué métodos faltan por implementar, en todos ellos se ha incluido la excepción ```raise NotImplementedError``` para poner de manifiesto que dicho método debe ser implementado.
#
# Se comienza importando librerías. El uso de otras librerías **basicas** también está permitido, siempre que esté justificado.

# %%
from __future__ import annotations

from abc import ABC, abstractmethod
import numpy as np
import copy
import math
import matplotlib.pyplot as plt
import itertools
import random

# %% [markdown]
# #### El módulo ```dilemma```
#
# El primer módulo que se recomienda implementar es el que recoge la información sobre el dilema jugado. Como el DP solo tiene dos acciones posibles (*Cooperate* y *Defect*), por simplicidad crearemos dos variables globales ```C``` y ```D``` asociadas a dos enteros (0 y 1 respectivamente). Representarán estas dos acciones a lo largo de todo el código:

# %%
C = 0
D = 1

printAction = {C: 'C', D: 'D'} # Diccionario usado para printear Cooperate y Defect de una manera mas legible
reverseAction = {C: D, D: C} # Diccionario para invertir la accion Cooperate <--> Defect

# %% [markdown]
# Ahora se propone implementar una clase llamada ```Dilemma``` para representar dilemas simétricos 2x2, como el dilema del prisionero.

# %%
class Dilemma:

    def __init__(self, cc: float, cd: float, dc: float, dd: float):
        """
        Represents a 2x2 symmetric dilemma.

        Parameters:
            - cc (float): payoff for mutual cooperation
            - cd (float): payoff when one cooperates, but the opponent defects
            - dc (float): payoff when one defects, and the opponent cooperates
            - dd (float): payoff for mutual defection
        """
        self.cc = cc
        self.cd = cd
        self.dc = dc
        self.dd = dd

    @property
    @abstractmethod
    def payoff_matrix(self) -> np.ndarray:
        """
        Symmetric pay-off matrix of the dilema

        Returns:
            - 2x2 np array of the matrix
        """
        return np.array([[self.cc, self.cd], [self.dc, self.dd]])


    @abstractmethod
    def evaluate_result(self, a_1: int, a_2: int) -> tuple[float, float]:
        """
        Given two actions, returns the payoffs of the two players.

        Parameters:
            - a_1 (int): action of player 1 ('C' or 'D', i.e. '1' or '0')
            - a_2 (int): action of player 2 ('C' or 'D', i.e. '1' or '0')

        Returns:
            - tuple of two floats, being the first and second values the payoff
            for the first and second player, respectively.
        """
        if a_1 == C:
            if a_2 == C:
                return (self.cc,self.cc)
            else:
                return (self.cd,self.dc)
        else:
            if a_2 == C:
                return (self.dc,self.cd)
            else:
                return (self.dd,self.dd)

# %% [markdown]
# Comprueba que los métodos anteriores funcionan correctamente con el siguiente test:

# %%
#Prints all possible outcomes of the PD
pd = Dilemma(2, -1, 3, 0)
posible_actions = (C, D)
for a1, a2 in itertools.product(posible_actions, repeat=2):
    print(f"{(a1, a2)} -> {pd.evaluate_result(a1, a2)}")

# Output:
# (0, 0) -> (2, 2)
# (0, 1) -> (-1, 3)
# (1, 0) -> (3, -1)
# (1, 1) -> (0, 0)
# Out:
# (0, 0) -> (2, 2)
# (0, 1) -> (-1, 3)
# (1, 0) -> (3, -1)
# (1, 1) -> (0, 0)

# %% [markdown]
# #### El módulo ```player```
#
# Ahora vamos a programar una módulo que sirva para representar a los jugadores. En particular, su método principal será ```strategy()```, que devolverá una acción a realizar, en base a la historia de interacción con otro jugador. Además, aprovecharemos a implementar los *jugadores ilustres*, aquellos que juegan estrategias famosas, para que luego sea sencillo hacer pruebas.
#
# Empezaremos programando una clase abstracta llamada ```player``` de la que heredarán los jugadores concretos que programaremos a continuación.

# %%
class Player(ABC):

    # Este método ya está implementado
    @abstractmethod
    def __init__(self, dilemma: Dilemma, name: str = ""):
        """
        Abstract class that represents a generic player

        Parameters:
            - name (str): the name of the strategy
            - dilemma (Dilemma): the dilemma that this player will play
        """

        self.name = name
        self.dilemma = dilemma

        self.history  = []  # This is the main variable of this class. It is
                            # intended to store all the history of actions
                            # performed by this player.
                            # Example: [C, C, D, D, D] <- So far, the
                            # interaction lasts five rounds. In the first one,
                            # this player cooperated. In the second, he also
                            # cooperated. In the third, he defected. Etc.

    
    def updateHistory(self, newAction):
        self.history.append(newAction)

    # Este método ya está implementado
    @abstractmethod
    def strategy(self, opponent: Player) -> int:
        """
        Main call of the class. Gives the action for the following round of the
        interaction, based on the history

        Parameters:
            - opponent (Player): is another instance of Player.

        Results:
            - An integer representing Cooperation (C=0) or Defection (D=1)
        """
        pass
 

    def compute_scores(self, opponent: Player, error: float) -> tuple[float, float]:
        """
        Compute the scores for a given opponent

        Parameters:
            - opponent (Player): is another instance of Player.

        Results:
            - A tuple of two floats, where the first value is the current
            player's payoff, and the second value is the opponent's payoff.
        """
        decision_1 = self.strategy(opponent)
        assert decision_1 in [C, D], f"Invalid action: {decision_1=}"
        decision_1 = reverseAction[decision_1] if random.random() < error else decision_1   


        decision_2= opponent.strategy(self)
        assert decision_2 in [C, D], f"Invalid action: {decision_2=}"
        decision_2 = reverseAction[decision_2] if random.random() < error else decision_2   


        self.updateHistory(decision_1)
        opponent.updateHistory(decision_2)

        return self.dilemma.evaluate_result(decision_1,decision_2)


    # Este método ya está implementado
    def clean_history(self):
        """Resets the history of the current player"""
        self.history = []


# A continuación se representan las 5 estrategias básicas del juego de Nicky Case

class Cooperator(Player):

    def __init__(self, dilemma: Dilemma, name: str = ""):
        """Cooperator"""
        super().__init__(dilemma, name)



    def strategy(self, opponent: Player) -> int:
        """Cooperates always"""
        return C


class Defector(Player):

    def __init__(self, dilemma: Dilemma, name: str = ""):
        """Defector"""
        super().__init__(dilemma, name)


    def strategy(self, opponent: Player) -> int:
        """Defects always"""
        return D


class Tft(Player):

    def __init__(self, dilemma: Dilemma, name: str = ""):
        """Tit-for-tat"""
        super().__init__(dilemma, name)



    def strategy(self, opponent: Player) -> int:
        """Cooperates first, then repeat last action of the opponent"""
        if len(opponent.history) == 0:
            return C
        return opponent.history[-1]


class Grudger(Player):

    def __init__(self, dilemma: Dilemma, name: str = ""):
        """Grudger"""
        self.beenBetrayed = False
        super().__init__(dilemma, name)


    def clean_history(self):
        self.beenBetrayed = False # Reiniciamos la variable beenBetrayed para "reiniciar" al jugador con la funcion clean_history
        return super().clean_history()

    def strategy(self, opponent: Player) -> int:
        """
        Cooperates always, but if opponent ever defects, it will defect for the
        rest of the game
        """
        
        if len(opponent.history)==0:
            return C
        elif self.beenBetrayed:
            return D
        elif opponent.history[-1] == D:
            self.beenBetrayed = True
            return D
        return C
        


class Detective4MovsTft(Player):

    def __init__(self, dilemma: Dilemma, name: str = ""):
        """Four movement - tit for tat detective"""
        self.discoveredTFT = False
        self.firstMoves =  [C,D,C,C]
        super().__init__(dilemma, name)

    def clean_history(self):
        self.discoveredTFT = False # Reiniciamos la variable discoveredTFT para "reiniciar" al jugador con la funcion clean_history
        return super().clean_history()

    def strategy(self, opponent: Player) -> int:
        """
        Starts with a fixed sequence of actions: [C,D,C,C]. After that, if
        the opponent has ever defected, plays 'TFT'. If not, plays 'Defector'.
        """
        if len(opponent.history) <4:
            if len(opponent.history)!=0 and opponent.history[-1] == D:
                self.discoveredTFT = True
            return self.firstMoves[len(opponent.history)]
        elif self.discoveredTFT:
            return opponent.history[-1]
        else:
            return D

# %% [markdown]
# Testearemos este módulo una vez programemos el siguiente
#
# #### El módulo ```game```
#
# Ya sabemos manejar jugadores. Ahora vamos a enfrentarles. El presente módulo pretende recoger las herramientas necesarias para enfrentar a dos jugadores en una *partida* del dilema del prisionero iterado. Está compuesto por una clase llamada ```Game``` que implementa el método principal ```play()```.

# %%
class Game:

    # Este método ya está implementado
    def __init__(self, player_1: Player,
                       player_2: Player,
                       n_rounds: int = 100,
                       error: float = 0.0):
        """
        Game class to represent an iterative dilema

        Parameters:
            - player_1 (Player): first player of the game
            - player_2 (Player): second player of the game
            - n_rounds (int = 100): number of rounds in the game
            - error (float = 0.0): error probability (in base 1)
        """

        assert n_rounds > 0, "'n_rounds' should be greater than 0"

        self.player_1 = player_1
        self.player_2 = player_2
        self.n_rounds = n_rounds
        self.error = error

        self.score = (0.0, 0.0)  # this variable will store the final result of
                                 # the game, once the 'play()' function has
                                 # been called. The two values of the tuple
                                 # correspond to the points scored by the first
                                 # an d second player, respectively.


    def play(self, do_print: bool = False) -> None:
        """
        Main call of the class. Play the game.
        Stores the final result in 'self.score'

        Parameters
            - do_print (bool = False): if True, should print the ongoing
            results at the end of each round (i.e. print round number, last
            actions of both players and ongoing score).
        """

        # Limpiamos los historiales de los jugadores para que empiecen sus estrategias desde cero
        self.player_1.clean_history()
        self.player_2.clean_history()
        
        for round in range(self.n_rounds):
            scores = self.player_1.compute_scores(self.player_2, self.error)
            self.score = (scores[0] +self.score[0], scores[1] + self.score[1])

            if do_print:
                print(f'Round number {round}')
                print(f'Player 1 choosed: {printAction[self.player_1.history[-1]]} // Player 2 choosed {printAction[self.player_2.history[-1]]}')
                print(f'Given score {scores}')
                print(f'Total score: {self.score}')
                print('-'*15)

        print(f' FINAL SCORE: PLAYER 1: {self.score[0]} // PLAYER 2: {self.score[1]}') if do_print else None

# %% [markdown]
# Comprueba que los últimos dos módulos funcionan como se espera en la siguiente celda. Experimenta con distintas combinaciones de jugadores y observa que los resultados son los esperados. Por ejemplo, un Cooperador y un Grudger se pasan toda su interacción cooperando, por lo que en un juego de 10 rondas sin error, ambos deben obtener 20 puntos al final. Comprueba también que el error se está tratando como corresponde. Por ejemplo, fíjalo en un valor alto (e.g. 0.2) y comprueba que en el enfrentamiento de un Cooperador con un Grudger alguno deserta en alguna ocasión. Comprueba también que puedes enfrentar dos jugadores que jueguen la misma estrategia (simplemente crea dos instancias del mismo jugador, con distintos nombres).

# %%
dilemma = Dilemma(2, -1, 3, 0)

cooperator_player = Cooperator(dilemma, "cooperator")
defector_player = Defector(dilemma, "defector")
tft_player = Tft(dilemma, "tft")
grudger_player = Grudger(dilemma, "grudger")
detective_player = Detective4MovsTft(dilemma, "detective")

#Modifica las siguientes líneas a conveniencia para llevar a cabo distintos tests
game = Game(defector_player, detective_player, n_rounds=10, error=0)
game.play(do_print=True)
# Out:
# Round number 0
# Player 1 choosed: D // Player 2 choosed C
# Given score (3, -1)
# Total score: (3.0, -1.0)
# ---------------
# Round number 1
# Player 1 choosed: D // Player 2 choosed D
# Given score (0, 0)
# Total score: (3.0, -1.0)
# ---------------
# Round number 2
# Player 1 choosed: D // Player 2 choosed C
# Given score (3, -1)
# Total score: (6.0, -2.0)
# ---------------
# Round number 3
# Player 1 choosed: D // Player 2 choosed C
# Given score (3, -1)
# Total score: (9.0, -3.0)
# ---------------
# Round number 4
# Player 1 choosed: D // Player 2 choosed D
# Given score (0, 0)
# Total score: (9.0, -3.0)
# ---------------
# Round number 5
# Player 1 choosed: D // Player 2 choosed D
# Given score (0, 0)
# Total score: (9.0, -3.0)
# ---------------
# Round number 6
# Player 1 choosed: D // Player 2 choosed D
# Given score (0, 0)
# Total score: (9.0, -3.0)
# ---------------
# Round number 7
# Player 1 choosed: D // Player 2 choosed D
# Given score (0, 0)
# Total score: (9.0, -3.0)
# ---------------
# Round number 8
# Player 1 choosed: D // Player 2 choosed D
# Given score (0, 0)
# Total score: (9.0, -3.0)
# ---------------
# Round number 9
# Player 1 choosed: D // Player 2 choosed D
# Given score (0, 0)
# Total score: (9.0, -3.0)
# ---------------
#  FINAL SCORE: PLAYER 1: 9.0 // PLAYER 2: -3.0

# %% [markdown]
# #### El módulo ```torunament```
#
# Finalmente, llegamos al módulo que nos va a permitir simular el campeonato.

# %%
class Tournament:

    # Este método ya está implementado
    def __init__(self, players: tuple[Player, ...],
                       n_rounds: int = 100,
                       error: float = 0.0,
                       repetitions: int = 2):
        """
        All-against-all tournament

        Parameters:
            - players (tuple[Player, ...]): tuple of players that will play the
         tournament
            - n_rounds (int = 100): number of rounds in the game
            - error (float = 0.0): error probability (in base 1)
            - repetitions (int = 2): number of games each player plays against
         the rest
        """

        self.players = players
        self.n_rounds = n_rounds
        self.error = error
        self.repetitions = repetitions

        # This is a key variable of the class. It is intended to store the
        # ongoing ranking of the tournament. It is a dictionary whose keys are
        # the players in the tournament, and its corresponding values are the
        # points obtained in their interactions with each other. In the end, to
        # see the winner, it will be enough to sort this dictionary by the
        # values.
        self.ranking = {player: 0.0 for player in self.players}  # initial vals


    def sort_ranking(self) -> None:
        """Sort the ranking by the value (score)"""
        self.ranking = dict(sorted(self.ranking.items(), key=lambda item: item[1], reverse=True))


    #pista: utiliza 'itertools.combinations' para hacer los cruces
    def play(self, do_print:bool = False) -> None:
        """
        Main call of the class. It must simulate the championship and update
        the variable 'self.ranking' with the accumulated points obtained by
        each player in their interactions.
        """
        for player_1, player_2 in itertools.combinations(self.players, 2):
            for _ in range(self.repetitions):
                game = Game(player_1, player_2, self.n_rounds, self.error)
                game.play()
                self.ranking[player_1] += game.score[0]
                self.ranking[player_2] += game.score[1]

                if do_print:
                    print(f'Player 1: {player_1.name} // Player 2: {player_2.name}')
                    print(f'Final score: {game.score}')
                    print('-'*15)
                
        self.sort_ranking()


    def plot_results(self):
        """
        Plots a bar chart of the final ranking. On the x-axis should appear
        the names of the sorted ranking of players participating in the
        tournament. On the y-axis the points obtained.
        """
        plt.figure(figsize=(10, 5))
        # Create numeric indices for the players
        x_positions = range(len(self.ranking))

        # Plot using numeric indices for the x-axis and player names as labels
        bars = plt.bar(x_positions, self.ranking.values())
        plt.xlabel('Players')
        plt.ylabel('Points')
        plt.title('Tournament results')

        for bar in bars:
            yval = bar.get_height()  # Get the height of the bar (the value)
            plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')  # Display value


        names = [player.name for player in self.ranking.keys()]
        # Set player names as x-tick labels
        plt.xticks(x_positions, names, rotation=45, ha="right")  # Rotate for better readability
        plt.tight_layout()  
        plt.show()

# %% [markdown]
# Para testear la implementación, por ejemplo prueba a reproducir el campeonato de la sección "3. One Tournament" del juego de Nicky Case. En dicho campeonato se enfrentaban las 5 estrategias básicas (cooperador, desertor, tft, grudger y detective) en un torneo con 10 rondas por interacción y sin error. Los resultados que debes obtener son los siguientes:
#  - Tit-For-Tat: ganador con 57 puntos
#  - Grudger: 46 puntos
#  - Detective: 45 puntos
#  - Desertor: 45 puntos
#  - Cooperador: 29 puntos

# %%
dilemma = Dilemma(2, -1, 3, 0)

cooperator_player = Cooperator(dilemma, "cooperator")
defector_player = Defector(dilemma, "defector")
tft_player = Tft(dilemma, "tft")
grudger_player = Grudger(dilemma, "grudger")
detective_player = Detective4MovsTft(dilemma, "detective")

all_players = (cooperator_player, defector_player, tft_player, grudger_player,
               detective_player)


tournament = Tournament(all_players, n_rounds=10, error=0.0, repetitions=1)
tournament.play(do_print=False)
tournament.plot_results()

# %% [markdown]
# #### El módulo ```evolution```
#
# Implementa también la variante evolutiva del torneo, similar a la que se explica en la sección "4. Repeated Tournament" del juego de Nicky Case. Este módulo necesitará de inputs extra. Ten en cuenta lo siguiente:
#  - La población inicial de jugadores no es directamente el input de jugadores que dé el usuario, sino que cada jugador tiene varios "individuos" o "réplicas" que jugarán su estrategia. Se propone dar al usuario dos opciones para definir esta población inicial:
#    - Si el usuario define el tamaño de la población total (```int```), se asume que cada jugador comienza con el mismo número de representantes. Divide ese número entre el número de jugadores (redondeado al entero más próximo) y así obtendrás el número de individuos inicial de cada estrategia.
#    - Si el usuario define una tupla de números de individuos (```list[int, ...]```), se asume que cada jugador tendrá el número de representantes que indique su índice dentro de dicha tupla.
#  - Hay dos parámetros más que controlan el proceso evolutivo.
#    - En primer lugar, el porcentaje de individuos que se desea incluir en la selección natural tras cada ronda; esto es, el número de individuos *de la parte de abajo del ranking* que se van a eliminar y sustituir por los *individuos de la parte de arriba* (en caso de empate entre individuos, escoge al azar).
#    - En segundo lugar, el número de generaciones que se van a simular. Una generación es básicamente un "Torneo de enfrentamiento directo" + un "Proceso de selección natural".
#
# Deberás tomar una decisión sobre qué hacer en la selección natural cuando hay *empates*.
#
# A continuación se incluye la plantilla de desarrollo sugerida.

# %%
class Evolution:

    # Este método ya está implementado
    def __init__(self, players: tuple[Player, ...],
                       n_rounds: int = 100,
                       error: float = 0.0,
                       repetitions: int = 2,
                       generations: int = 100,
                       reproductivity: float = 0.05,
                       initial_population: tuple[int, ...] | int = 100):
        """
        Evolutionary tournament

        Parameters:
            - players (tuple[Player, ...]): tuple of players that will play the
         tournament
            - n_rounds (int = 100): number of rounds in each game
            - error (float = 0.0): error probability (in base 1)
            - repetitions (int = 2): number of games each player plays against
         the rest
            - generations (int = 100): number of generations to simulate
            - reproductivity (float = 0.05): ratio (base 1) of worst players
         that will be removed and substituted by the top ones in the natural
         selection process carried out at the end of each generation
            - initial_population (tuple[int, ...] | int = 100): list of
         individuals representing each players (same index as 'players' tuple)
         OR total population size (int).
        """

        self.count_evolution = None
        self.players = players
        self.n_rounds = n_rounds
        self.error = error
        self.repetitions = repetitions
        self.generations = generations
        self.reproductivity = reproductivity

        if isinstance(initial_population, int):
            self.initial_population = [math.floor(initial_population
                                       / len(self.players))
                                       for _ in range(len(self.players))]
        else:
            self.initial_population = initial_population

        self.total_population = sum(self.initial_population)
        self.repr_int = int(self.total_population * self.reproductivity)

        self.ranking = {copy.deepcopy(player): 0.0 for i, player in
                        enumerate(self.players)
                        for _ in range(self.initial_population[i])}


    def natural_selection(self, result_tournament: dict[Player, float]) \
                          -> tuple[list,list]:
        """
        Kill the worst guys, reproduce the top ones. Takes the ranking once a
        face-to-face tournament has been played and returns another ranking,
        with the evolutionary changes applied

        Parameters:
            - result_tournament: the 'tournament.ranking' kind of dict.

        Results:
            - Same kind of dict ranking as the input, but with the evolutionary
         dynamics applied
        """
        sorted_ranking = dict(sorted(result_tournament.items(), key=lambda item: item[1], reverse=True))

        values_sorted = list(sorted_ranking.values())
        top_players = []

        ## Con este if controlamos el caso en el que hay empate en el último puesto y seleccionamos a los jugadores que empatan aleatoriamente
        if values_sorted[self.repr_int] == values_sorted[self.repr_int+1]:
            num_higher_values = sum([1 for val in values_sorted if val > values_sorted[self.repr_int]])
            num_draw_values = self.repr_int - num_higher_values

            random_numbers = random.sample(range(num_higher_values, num_higher_values + num_draw_values+1), num_draw_values)
            # Añadimos a la lista de mejores jugadores aquellos que empatan en el ultimo puesto
            for i in random_numbers:
               top_players.append(list(sorted_ranking.keys())[i])
            top_players += list(sorted_ranking.keys())[:num_higher_values]
            
        else:
            top_players = list(sorted_ranking.keys())[:self.repr_int]
        
        top_players_copy = copy.deepcopy(top_players) # Copiamos a los mejores jugadores, ya que posteriormente los metemos a un diccionario
        new_players = [player for player in list(sorted_ranking.keys())[:-self.repr_int]]
        new_players += top_players_copy # Combinamos los jugadores conservados de la iteracion anterior con los mejores
           
        return {player: 0.0 for player in new_players}
        

    def count_strategies(self) -> dict[str, int]:
        """
        Counts the number of played alive of each strategy, based on the
        initial list of players. Should be computed analyzing the
        'self.ranking' variable. Useful for the results plot/print (not needed
        for the tournament itself)

        Results:
            - A dict, containing as values the name of the players and as
         values the number of individuals they have now alive in the tournament
        """
        counter = {player.name: 0 for player in self.players}
        for player in self.ranking.keys():
            counter[player.name] += 1
        return counter


    def play(self, do_print: bool = False):
        """
        Main call of the class. Performs the computations to simulate the
        evolutionary tournament.

        Parameters
            - do_print (bool = False): if True, should print the ongoing
         results at the end of each generation (i.e. print generation number,
         and number of individuals playing each strategy).
        """

        # HINT: Initialise the following variable
        #  > count_evolution = {player.name: [val] for player, val in
        #                       zip(self.players, self.initial_population)}
        # and use it to store the number of individuals each player retains at
        # the end of each generation, appending to its corresponding list value
        # the number of individuals each player has (obtained by calling
        # 'self.count_strategies()'). For example, at some point, it could have
        # the following value:
        # {'cooperator': [15, 10, 5, 0, 0, 0, 0, 0, 0, 0, 0],
        #  'defector': [5, 10, 15, 19, 14, 9, 4, 0, 0, 0, 0],
        #  'tft': [5, 5, 5, 6, 11, 16, 21, 25, 25, 25, 25]}

        count_evolution = {player.name: [val] for player, val in zip(self.players, self.initial_population)}

        if do_print:
            print(f'Initial number of individuals playing each strategy: {self.count_strategies()}')
            print('-'*15)
        
        for generation in range(self.generations):        
            tournament = Tournament(list(self.ranking.keys()), self.n_rounds, self.error, self.repetitions)
            tournament.play()
            
            self.ranking = self.natural_selection(tournament.ranking)

            count_strategies_it = self.count_strategies()
            count_evolution = {player_name: count_evolution[player_name] + [count_strategies_it[player_name]] for player_name in count_evolution.keys()}
            if do_print:
                print(f'Generation number {generation+1}')
                # print(f'Points in generation: {tournament.ranking}')
                print(f'Number of individuals playing each strategy: {self.count_strategies()}')
                print('-'*15)

        self.count_evolution = count_evolution
        if do_print:
            self.stackplot(count_evolution)

    # Si quieres obtener un buen gráfico de la evolución, puedes usar este
    # método si has seguido la pista indicada en la cabecera del método
    # anterior. Ya está implementado, pero puede que necesites adaptarlo a tu
    # código.
    def stackplot(self, count_evolution: dict[str, list]) -> None:
        """
        Plots a 'stackplot' of the evolution of the tournament

        Parameters:
            - count_evolution (dict[Player, list]): a dictionary containing as
         keys the name of the strategies of the different players of the
         tournament. Each value is a list, where the 'i'-th position of that
         list indicates the number of individuals that player has at the end of
         the 'i'-th generation
         """
        plt.figure(figsize=(20, 10))
        COLORS = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black']

        for i, name in enumerate(count_evolution.keys()):
            plt.plot([], [], label=name, color= COLORS[(i) % len(COLORS)])

        plt.stackplot(list(range(self.generations + 1)),
                      np.array(list(count_evolution.values())), colors=COLORS)

        plt.legend()
        plt.show()

# %% [markdown]
# Para testear el módulo anterior, puedes usar alguno de los experimentos mostrados en el juego de Nicky Case. Por ejemplo, un torneo con 5 TFT, 5 Desertores y 15 Cooperantes, sin error, con 10 rondas por interacción, con una reproductividad del 0.2, parece que en menos de 10 generaciones converge a una población dominada por TFT. Intenta replicar este resultado como se muestra a continuación:

# %%
dilemma = Dilemma(2, -1, 3, 0)

cooperator_player = Cooperator(dilemma, "cooperator")
defector_player = Defector(dilemma, "defector")
tft_player = Tft(dilemma, "tft")

all_players = (cooperator_player, defector_player, tft_player)

# evolution = Evolution(all_players, n_rounds=10, error=0.00, repetitions=1,
#                       generations=10, reproductivity=0.2,
#                       initial_population=(15, 5, 5))

evolution = Evolution(all_players, n_rounds=100, error=0.55, repetitions=1,
                      generations=10, reproductivity=0.3
                      ,
                      initial_population=(10, 10, 10))

evolution.play(True)
# Out:
# Initial number of individuals playing each strategy: {'cooperator': 10, 'defector': 10, 'tft': 10}
# ---------------
# Generation number 1
# Number of individuals playing each strategy: {'cooperator': 18, 'defector': 1, 'tft': 11}
# ---------------
# Generation number 2
# Number of individuals playing each strategy: {'cooperator': 27, 'defector': 0, 'tft': 3}
# ---------------
# Generation number 3
# Number of individuals playing each strategy: {'cooperator': 30, 'defector': 0, 'tft': 0}
# ---------------
# Generation number 4
# Number of individuals playing each strategy: {'cooperator': 30, 'defector': 0, 'tft': 0}
# ---------------
# Generation number 5
# Number of individuals playing each strategy: {'cooperator': 30, 'defector': 0, 'tft': 0}
# ---------------
# Generation number 6
# Number of individuals playing each strategy: {'cooperator': 30, 'defector': 0, 'tft': 0}
# ---------------
# Generation number 7
# Number of individuals playing each strategy: {'cooperator': 30, 'defector': 0, 'tft': 0}
# ---------------
# Generation number 8
# Number of individuals playing each strategy: {'cooperator': 30, 'defector': 0, 'tft': 0}
# ---------------
# Generation number 9
# Number of individuals playing each strategy: {'cooperator': 30, 'defector': 0, 'tft': 0}
# ---------------
# Generation number 10
# Number of individuals playing each strategy: {'cooperator': 30, 'defector': 0, 'tft': 0}
# ---------------

# %% [markdown]
# ¡Enhorabuena! La primera parte de la práctica ya la has terminado. En la siguiente sección, tendrás que diseñar una estrategia para participar en un triple campeonato.

# %% [markdown]
# ## Parte 2: diseño de una estrategia
#
# A continuación deberás implementar una estrategia que se enfrentará a las de tus compañeros un un torneo. Antes de describir las condiciones del campeonato, vamos a ver un concepto nuevo.
#
# Los juegos contra tus rivales tendrán un final **no determinista**. Esto quiere decir que el número de rondas que se van a jugar no se sabe con precisión. En lugar de eso, después de cada ronda, la partida tiene una cierta probabilidad de acabar (pequeña). ¿Por qué haremos esto? En verdad, el dilema del prisionero con una duración finita es un problema completamente distinto, ya que la proximidad del final de la interacción juega un papel crucial en las decisiones de las estrategias.
#
# Con el objetivo de dejar esta complejidad adicional fuera, jugaremos un número de rondas aleatorio: puedes pensar que tu estrategia va a jugar "muchas veces" contra cada rival. **En media, se jugarán 100 rondas** (puedes quedarte con ese número). Por supuesto, para que los resultados no estén determinados por el número de rondas jugadas, los puntos obtenidos en cada interacción se normalizarán por el número de rondas jugadas.

# %% [markdown]
# ### Descripción del campeonato
# Ahora sí, vamos a ver las condiciones del torneo. Hay tres fases en esta competición:
#  - Fase de enfrentamiento directo entre estrategias
#  - Fase evolutiva
#  - Fase evolutiva dentro del ecosistema completo del DPI

# %% [markdown]
# #### Fase de enfrentamiento directo entre estrategias
#
# Se jugará un torneo de *todos contra todos*: te enfrentarás a las estrategias de tus rivales dos veces. El resultado que obtengas en cada enfrentamiento se sumará a los ya obtenidos hasta el momento. Ganará la estrategia con más puntos al final de las interacciones. Las condiciones concretas son las siguientes:
#  - El dilema del prisionero que se usará será el siguiente:
#
# <center>
#
# |      |  C    |  D    |
# |------|-------|-------|
# |   C  | 13, 13  | 0, 18  |
# |   D  | 18, 0  | 4, 4  |
#
# </center>
#
#  - La probabilidad de acabar el enfrentamiento tras cada ronda $P_{end}$ se fija en 1%, con un máximo de rondas de 300.
#  - La probabilidad de error $P_{error}$ se fija en 0.8%.
#  - Se jugará 2 veces contra cada rival.
#
# Se asignarán los siguientes puntos según la posición final:
#  - 5º y 6º clasificados: 4 puntos
#  - 4º clasificado: 8 puntos
#  - 3º clasificado: 12 puntos
#  - 2º clasificado: 17 puntos
#  - 1º clasificado: 24 puntos

# %% [markdown]
# #### Fase evolutiva
#
# Las estrategias se enfrentarán en un torneo evolutivo, en el que todos parten con el mismo número de representantes. Las condiciones para cada generación son las mismas que en la fase anterior.
#
# La reproductividad se manejará de forma ligeramente distinta a lo visto en secciones anteriores. Ahora, en sucesivas generaciones, la proporción de individuos de un jugador frente al total será la misma que la proporción de puntos obtenidos por todos esos individuos frente al total de puntos obtenidos por todas las estrategias. Por ejemplo, imagina que una determinada generación tienes 17 individuos de un total de 100. Estos individuos, en suma han obtenido un total de 210 puntos. Además, la suma de puntos obtenidos por todas las individuos de la población es 1000 puntos. Por tanto, en la siguiente generación dispondrás de 21 individuos.
#
# Aquí la evaluación de los ganadores puede ser complicada. En principio, el orden en el que se extingan las estrategias indicará el ranking de esta fase. No obstante, en ocasiones surgen situaciones difíciles de evaluar (por ejemplo, comportamientos cíclicos de dominancia de varias estrategias). En este tipo de escenarios, serán los profesores quienes decidan qué estrategias han sido las más exitosas y su orden. Los puntos que pueden obtenerse en esta fase son los siguientes:
#  - 3º clasificado: 12 puntos
#  - 2º clasificado: 17 puntos
#  - 1º clasificado: 24 puntos

# %% [markdown]
# #### Fase evolutiva dentro del ecosistema completo del DPI
#
# En esta fase, tu estrategia se enfrentará en un gran torneo evolutivo, donde estarán incluidas las estrategias de tus compañeros, pero también hasta 50 estrategias adicionales del ecosistema del DPI. Estarán las que ya conoces (TFT, Grudger, etc.), y también las estrategias que se han mostrado más exitosas en las últimas publicaciones científicas. De nuevo, el criterio general para establecer el ranking entre nuestras estrategias será: "cuanto más tarde se extingan tus individuos, más alto estarás en el ranking". Al haber tantas estrategias involucradas, esta parte del campeonato es la más susceptible a presentar situaciones difíciles de evaluar, por lo que en última instancia serán los profesores quienes, partiendo de criterios objetivos, seleccionen las tres estrategias más exitosas, que se llevarán:
#  - 3º clasificado: 4 puntos
#  - 2º clasificado: 8 puntos
#  - 1º clasificado: 12 puntos
#
# Los puntos de las tres fases se sumarán y **el grupo ganador obtendrá 0.4 puntos extra en la evaluación de la asignatura**.

# %% [markdown]
# ### Implementación de tu estrategia
#
# A la hora de implementar tu estrategia ten en cuenta lo siguiente:
#  - Si has seguido la plantilla de desarrollo de la primera parte de la práctica, tu estrategia deberá ser implementada como un subclase de la clase abstracta ```Player()```. En particular, debes implementar cuidadosamente su método ```strategy()```.
#  - No olvides darle un buen nombre a tu estrategia.
#  - Igualmente, mientras implementas, incluye todo los comentarios que puedan ayudar a los profesores a evaluar positivamente tu estrategia. Por ejemplo: "*he visto que mi estrategia funcionaba mal contra Desertores, por eso incluyo el siguiente bloque de código que pretende...*".
#  - **¡IMPORTANTE!** Incluye información suficientemente extensa para explicar tus decisiones de diseño, por qué presentas esa estrategia y no otra, cuáles son los resultados que has observado en las pruebas que has hecho, qué problemas te has encontrado y cómo los has solucionado, etc.
#
# A continuación se incluye un ejemplo de implementación de una estrategia. De hecho, este ejemplo será la estrategia de los profesores, ¡y participará en el campeonato! Así que ya sabes una de las estrategias que va a estar presente.

# %%
class Destructomatic(Player):

    def __init__(self, dilemma: Dilemma, name: str = ""):
        super().__init__(dilemma, name)
        self.defection_count = 0
        self.consecutive_cooperation = 0
        self.rounds_to_defect = 0

    def strategy(self, opponent: Player) -> int:
        """
        A gradual forgiveness strategy.
        Starts cooperating, increases defection periods for repeated defections,
        and resets after a series of cooperations.
        """

        turns = len(self.history)

        if turns == 0:  # First move, always cooperate
            return C

        if self.rounds_to_defect > 0:
            self.rounds_to_defect -= 1
            return D  # Defect if we're in a defection period

        last_move = opponent.history[-1]

        if last_move == C:
            self.consecutive_cooperation += 1
            if self.consecutive_cooperation >= 5:
                self.defection_count = 0
                self.consecutive_cooperation = 0
        else:  # Opponent defected
            self.defection_count += 1
            self.consecutive_cooperation = 0
            self.rounds_to_defect = self.defection_count
            return D  # Defect immediately after opponent's defection

        return C  # Cooperate otherwise

# %% [markdown]
# #### Espacio para el desarrollo de tu estrategia
#
# Implementa tu estrategia en la plantilla de la siguiente celda, modificándola a conveniencia. Puedes añadir más métodos si lo necesitas. Incluye una descripción explicando el proceso que has seguido para diseñarla: usa el docstring de tu clase o una celda de texto adicional.

# %%
# Dado que la estrategia de tft funciona bastante bien para entornos sin probabilidad de error, vamos a implementar una estrategia similar
# pero teniendo en cuenta la probabilidad de error

class Forgiving_TFT(Player):

    def __init__(self, dilemma: Dilemma, name: str = "",prob_error:float = 0.008):
        super().__init__(dilemma, name)

        self.recent_opponent_defects = 0 # Numero de veces que se no ha cooperado el oponente recientemente

        self.num_rounds_last_oponent_defect = 0 # Numero de rondas desde la ultima vez que no coopero el oponente

        # Numero de rondas en las cuales esperamos para ver si el oponente decide no cooperar mas de una vez 
        self.MEAN_ROUNDS_TO_FORGIVE =  (1/prob_error) # Numero medio de rondas que tardaria un individuo en equivocarse


    def strategy(self, opponent: Player) -> int:
        """
        Esta estrategia consiste en implementar un Tit-for-Tat (TFT), pero 
        sabiendo que el oponente puede equivocarse con una probabilidad de error.

        De esta forma, la estrategia siempre cooperara a menos que detecte que el oponente
        no esta cooperando intencionadamente. En tal caso la estrategia dejara de cooperar
        durante un numero de rondas.
        """

        if len(opponent.history) == 0:
            return C
        
        # Si no coopera aumentamos los contadores
        if opponent.history[-1] == D:
            self.num_rounds_last_oponent_defect = 0
            self.recent_opponent_defects += 1
        
        # Si hace mucho tiempo que no ha dejado de cooperar, suponemos que el oponente quiere cooperar y cuando no coopero fue por error
        if (self.num_rounds_last_oponent_defect >= self.MEAN_ROUNDS_TO_FORGIVE) and (self.recent_opponent_defects > 0):
            self.recent_opponent_defects -=1
        
        # Si no coopero y no fue por error, tampoco cooperamos, pero por si acaso fue un error, 
        # unicamente descontamos 1 del numero reciente de no cooperaciones del oponente
        if self.recent_opponent_defects > 1:
            self.recent_opponent_defects -= 1
            return D
        
        return C

# %% [markdown]
# Para la entrega, explica en detalle el proceso de diseño de tu estrategía, por qué has decidido presentar esa estrategia y no otras con las que hayas probado, qué consideraciones has tenido en cuenta al diseñarla, etc.

# %%
# Haz todas las pruebas que necesites aquí.
# Por ejemplo:

dilemma = Dilemma(13, 0, 18, 4)
participants = (Destructomatic(dilemma, "destr"),
                Cooperator(dilemma, "coop1"),
                Defector(dilemma, "defect"),
                Cooperator(dilemma, "coop2"),
                Tft(dilemma, "tft"),
                Detective4MovsTft(dilemma, "detect"),
                Forgiving_TFT(dilemma,"forgiving tft"))

tournament = Tournament(participants, n_rounds=100, error=0.008,
                         repetitions=2)
tournament.play()
tournament.plot_results()

# %% [markdown]
# Vemos que la estrategia de forgiving tft no es la mejor de todas en los torneos. Vamos a ver que tan bien funciona en la fase evolutiva

# %%
# Probamos que tal es el Forgiving_TFT en comparacion con el resto de estrategias.
dilemma = Dilemma(13, 0, 18, 4)
participants = (Destructomatic(dilemma, "destr"),
                Cooperator(dilemma, "coop1"),
                Defector(dilemma, "defect"),
                Cooperator(dilemma, "coop2"),
                Tft(dilemma, "tft"),
                Detective4MovsTft(dilemma, "detect"),
                Forgiving_TFT(dilemma,"forgiving_tft"))

evolution = Evolution(participants, n_rounds=100, error=0.008, repetitions=1,
                      generations=30, reproductivity=0.3
                      ,
                      initial_population=(10, 10, 10,10,10,10,10))

evolution.play(True)
# Out:
# Initial number of individuals playing each strategy: {'destr': 10, 'coop1': 10, 'defect': 10, 'coop2': 10, 'tft': 10, 'detect': 10, 'forgiving_tft': 10}
# ---------------
# Generation number 1
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 10, 'defect': 0, 'coop2': 9, 'tft': 16, 'detect': 20, 'forgiving_tft': 15}
# ---------------
# Generation number 2
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 17, 'detect': 40, 'forgiving_tft': 13}
# ---------------
# Generation number 3
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 14, 'detect': 40, 'forgiving_tft': 16}
# ---------------
# Generation number 4
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 16, 'detect': 36, 'forgiving_tft': 18}
# ---------------
# Generation number 5
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 21, 'detect': 31, 'forgiving_tft': 18}
# ---------------
# Generation number 6
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 24, 'detect': 29, 'forgiving_tft': 17}
# ---------------
# Generation number 7
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 25, 'detect': 30, 'forgiving_tft': 15}
# ---------------
# Generation number 8
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 25, 'detect': 32, 'forgiving_tft': 13}
# ---------------
# Generation number 9
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 29, 'detect': 31, 'forgiving_tft': 10}
# ---------------
# Generation number 10
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 27, 'detect': 33, 'forgiving_tft': 10}
# ---------------
# Generation number 11
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 26, 'detect': 30, 'forgiving_tft': 14}
# ---------------
# Generation number 12
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 27, 'detect': 27, 'forgiving_tft': 16}
# ---------------
# Generation number 13
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 27, 'detect': 22, 'forgiving_tft': 21}
# ---------------
# Generation number 14
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 28, 'detect': 19, 'forgiving_tft': 23}
# ---------------
# Generation number 15
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 26, 'detect': 15, 'forgiving_tft': 29}
# ---------------
# Generation number 16
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 32, 'detect': 7, 'forgiving_tft': 31}
# ---------------
# Generation number 17
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 30, 'detect': 8, 'forgiving_tft': 32}
# ---------------
# Generation number 18
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 28, 'detect': 8, 'forgiving_tft': 34}
# ---------------
# Generation number 19
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 34, 'detect': 6, 'forgiving_tft': 30}
# ---------------
# Generation number 20
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 33, 'detect': 3, 'forgiving_tft': 34}
# ---------------
# Generation number 21
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 34, 'detect': 3, 'forgiving_tft': 33}
# ---------------
# Generation number 22
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 33, 'detect': 4, 'forgiving_tft': 33}
# ---------------
# Generation number 23
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 33, 'detect': 3, 'forgiving_tft': 34}
# ---------------
# Generation number 24
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 37, 'detect': 2, 'forgiving_tft': 31}
# ---------------
# Generation number 25
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 38, 'detect': 1, 'forgiving_tft': 31}
# ---------------
# Generation number 26
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 40, 'detect': 1, 'forgiving_tft': 29}
# ---------------
# Generation number 27
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 37, 'detect': 1, 'forgiving_tft': 32}
# ---------------
# Generation number 28
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 35, 'detect': 2, 'forgiving_tft': 33}
# ---------------
# Generation number 29
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 39, 'detect': 1, 'forgiving_tft': 30}
# ---------------
# Generation number 30
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 44, 'detect': 0, 'forgiving_tft': 26}
# ---------------

# %%
# Parece que funciona bien, sin embargo  probamos con otra semilla random, por si acaso solo gano por suerte

dilemma = Dilemma(13, 0, 18, 4)
participants = (Destructomatic(dilemma, "destr"),
                Cooperator(dilemma, "coop1"),
                Defector(dilemma, "defect"),
                Cooperator(dilemma, "coop2"),
                Tft(dilemma, "tft"),
                Detective4MovsTft(dilemma, "detect"),
                Forgiving_TFT(dilemma,"forgiving_tft"))

evolution = Evolution(participants, n_rounds=100, error=0.008, repetitions=1,
                      generations=30, reproductivity=0.3
                      ,
                      initial_population=(10, 10, 10,10,10,10,10))

evolution.play(True)
# Out:
# Initial number of individuals playing each strategy: {'destr': 10, 'coop1': 10, 'defect': 10, 'coop2': 10, 'tft': 10, 'detect': 10, 'forgiving_tft': 10}
# ---------------
# Generation number 1
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 10, 'defect': 0, 'coop2': 9, 'tft': 15, 'detect': 20, 'forgiving_tft': 16}
# ---------------
# Generation number 2
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 15, 'detect': 40, 'forgiving_tft': 15}
# ---------------
# Generation number 3
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 16, 'detect': 36, 'forgiving_tft': 18}
# ---------------
# Generation number 4
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 18, 'detect': 32, 'forgiving_tft': 20}
# ---------------
# Generation number 5
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 22, 'detect': 29, 'forgiving_tft': 19}
# ---------------
# Generation number 6
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 22, 'detect': 30, 'forgiving_tft': 18}
# ---------------
# Generation number 7
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 22, 'detect': 28, 'forgiving_tft': 20}
# ---------------
# Generation number 8
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 18, 'detect': 31, 'forgiving_tft': 21}
# ---------------
# Generation number 9
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 16, 'detect': 32, 'forgiving_tft': 22}
# ---------------
# Generation number 10
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 13, 'detect': 29, 'forgiving_tft': 28}
# ---------------
# Generation number 11
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 11, 'detect': 29, 'forgiving_tft': 30}
# ---------------
# Generation number 12
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 11, 'detect': 20, 'forgiving_tft': 39}
# ---------------
# Generation number 13
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 11, 'detect': 16, 'forgiving_tft': 43}
# ---------------
# Generation number 14
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 10, 'detect': 14, 'forgiving_tft': 46}
# ---------------
# Generation number 15
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 13, 'detect': 8, 'forgiving_tft': 49}
# ---------------
# Generation number 16
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 15, 'detect': 5, 'forgiving_tft': 50}
# ---------------
# Generation number 17
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 11, 'detect': 5, 'forgiving_tft': 54}
# ---------------
# Generation number 18
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 14, 'detect': 3, 'forgiving_tft': 53}
# ---------------
# Generation number 19
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 13, 'detect': 3, 'forgiving_tft': 54}
# ---------------
# Generation number 20
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 10, 'detect': 1, 'forgiving_tft': 59}
# ---------------
# Generation number 21
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 14, 'detect': 2, 'forgiving_tft': 54}
# ---------------
# Generation number 22
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 16, 'detect': 0, 'forgiving_tft': 54}
# ---------------
# Generation number 23
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 20, 'detect': 0, 'forgiving_tft': 50}
# ---------------
# Generation number 24
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 22, 'detect': 0, 'forgiving_tft': 48}
# ---------------
# Generation number 25
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 17, 'detect': 0, 'forgiving_tft': 53}
# ---------------
# Generation number 26
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 18, 'detect': 0, 'forgiving_tft': 52}
# ---------------
# Generation number 27
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 16, 'detect': 0, 'forgiving_tft': 54}
# ---------------
# Generation number 28
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 15, 'detect': 0, 'forgiving_tft': 55}
# ---------------
# Generation number 29
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 15, 'detect': 0, 'forgiving_tft': 55}
# ---------------
# Generation number 30
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 15, 'detect': 0, 'forgiving_tft': 55}
# ---------------

# %% [markdown]
# El Forgiving_TFT funciona bastante bien, sin embargo parece que no puede contra tft. Esto puede ser porque la probabilidad de error es muy pequeña y en una ronda es muy poco probable que los jugadores se equivoquen.
#
# Vamos a intentar utilizar una estrategia que se aproveche de estas 2 mejores estrategias para ganarles.

# %%
class Counter_TFT(Player):

    def __init__(self, dilemma: Dilemma, name: str = "",error_prob = 0.008):
        super().__init__(dilemma, name)

        self.error_prob = error_prob
        self.FIRST_MOVES = [D,C,D,C]
        
        self.simple_strategy = []
        

    def strategy(self, opponent: Player) -> int:
        """
        Podemos intentar averiguar las estrategias de los oponentes para saber si perdonan o no y aprovecharnos de eso.
        Por ello si perdonan las no cooperaciones, de vez en cuando no cooperamos. 
        Si no perdonan pero se acaban cooperando siempre cooperamos (ya que al final acabaremos ganando mas puntos aunque el oponente tambien) 
        Sin embargo si no responden a nuestra estrategia nos aprovechamos de ella (si coopera cooperamos sino no cooperamos).
        """

        # Realizamos los movimientos predeterminados
        if len(self.history) < len(self.FIRST_MOVES):
            return self.FIRST_MOVES[len(self.history)]

        # Observamos el historial para analizar al rival. Dado que la probabilidad de error es muy baja vamos a suponer que aun no se han equivocado
        if len(self.history) == len(self.FIRST_MOVES):
            # Vemos si es un tft
            if opponent.history[2] == C and opponent.history[3] == D:
                # vemos si perdono la primera no cooperacion
                if opponent.history[1] == D:
                    # Es un tft
                    # Nuestra estrategia va a ser siempre cooperar ya que sabemos que tft acabara cooperando tambien, maximizando nuestros puntos
                    self.simple_strategy = [C] 
                
                # si nos perdono solo la primera vez
                else:
                    # Es una implementacion que perdona
                    # Nuestra estrategia va a ser siempre cooperar hasta que llevemos por ejemplo 1/prob_error rondas cooperando, donde no
                    # cooperamos porque es muy probable que nos perdone

                    self.simple_strategy = ([C]* int(1/self.error_prob)) + [D]
            
            # Si parece que no se ha reaccionado a nuestros movimientos, suponiendo que no se ha equivocado 
            else:
                # si siempre ha cooperado
                if opponent.history[0] == C and opponent.history[1] == C and opponent.history[2] == C and \
                    opponent.history[3] == C:

                    # Es un algoritmo que coopera siempre, nos aprovechamos de el nunca cooperando
                    self.simple_strategy = [D]
                
                # si tras la no cooperacion no ha cooperado, podemos suponer que nunca lo hara
                if opponent.history[1] == D and opponent.history[2] == D and \
                    opponent.history[3] == D:

                    # por tanto no cooperamos
                    self.simple_strategy = [D]


        # Si hemos encontrado una estrategia buena, realizamos la estrategia ya programada en base al oponente
        if len(self.simple_strategy) > 0:
            return self.simple_strategy[len(opponent.history)%len(self.simple_strategy)]
        
        # Si no hemmos encontrado una estrategia buena, hacemos un tft
        else:
            return opponent.history[-1]

# %%
# Probamos un torneo con el Counter_TFT para ver como funciona

dilemma = Dilemma(13, 0, 18, 4)
participants = (Destructomatic(dilemma, "destr"),
                Cooperator(dilemma, "coop1"),
                Defector(dilemma, "defect"),
                Cooperator(dilemma, "coop2"),
                Tft(dilemma, "tft"),
                Detective4MovsTft(dilemma, "detect"),
                Forgiving_TFT(dilemma,"forgiving tft"),
                Counter_TFT(dilemma,"counter_tft"))

tournament = Tournament(participants, n_rounds=100, error=0.008,
                         repetitions=2)
tournament.play()
tournament.plot_results()

# %% [markdown]
# En el torneo funciona bastante bien, vemos que tal en el evolutivo

# %%
dilemma = Dilemma(13, 0, 18, 4)
participants = (Destructomatic(dilemma, "destr"),
                Cooperator(dilemma, "coop1"),
                Defector(dilemma, "defect"),
                Cooperator(dilemma, "coop2"),
                Tft(dilemma, "tft"),
                Detective4MovsTft(dilemma, "detect"),
                Forgiving_TFT(dilemma,"forgiving_tft"),
                Counter_TFT(dilemma,"counter_tft"))

evolution = Evolution(participants, n_rounds=100, error=0.008, repetitions=2,
                      generations=30, reproductivity=0.3
                      ,
                      initial_population=(10, 10, 10, 10, 10, 10, 10, 10))

evolution.play(True)
# Out:
# Initial number of individuals playing each strategy: {'destr': 10, 'coop1': 10, 'defect': 10, 'coop2': 10, 'tft': 10, 'detect': 10, 'forgiving_tft': 10, 'counter_tft': 10}
# ---------------
# Generation number 1
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 8, 'defect': 0, 'coop2': 8, 'tft': 13, 'detect': 20, 'forgiving_tft': 11, 'counter_tft': 20}
# ---------------
# Generation number 2
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 15, 'detect': 29, 'forgiving_tft': 13, 'counter_tft': 23}
# ---------------
# Generation number 3
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 12, 'detect': 12, 'forgiving_tft': 11, 'counter_tft': 45}
# ---------------
# Generation number 4
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 4, 'detect': 2, 'forgiving_tft': 5, 'counter_tft': 69}
# ---------------
# Generation number 5
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 3, 'detect': 0, 'forgiving_tft': 5, 'counter_tft': 72}
# ---------------
# Generation number 6
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 2, 'detect': 0, 'forgiving_tft': 6, 'counter_tft': 72}
# ---------------
# Generation number 7
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 3, 'detect': 0, 'forgiving_tft': 7, 'counter_tft': 70}
# ---------------
# Generation number 8
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 2, 'counter_tft': 78}
# ---------------
# Generation number 9
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 2, 'counter_tft': 78}
# ---------------
# Generation number 10
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 4, 'counter_tft': 76}
# ---------------
# Generation number 11
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 8, 'counter_tft': 72}
# ---------------
# Generation number 12
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 11, 'counter_tft': 69}
# ---------------
# Generation number 13
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 8, 'counter_tft': 72}
# ---------------
# Generation number 14
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 3, 'counter_tft': 77}
# ---------------
# Generation number 15
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 6, 'counter_tft': 74}
# ---------------
# Generation number 16
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 12, 'counter_tft': 68}
# ---------------
# Generation number 17
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 1, 'counter_tft': 79}
# ---------------
# Generation number 18
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 2, 'counter_tft': 78}
# ---------------
# Generation number 19
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 3, 'counter_tft': 77}
# ---------------
# Generation number 20
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 6, 'counter_tft': 74}
# ---------------
# Generation number 21
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 10, 'counter_tft': 70}
# ---------------
# Generation number 22
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 1, 'counter_tft': 79}
# ---------------
# Generation number 23
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 1, 'counter_tft': 79}
# ---------------
# Generation number 24
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 1, 'counter_tft': 79}
# ---------------
# Generation number 25
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 2, 'counter_tft': 78}
# ---------------
# Generation number 26
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 4, 'counter_tft': 76}
# ---------------
# Generation number 27
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 7, 'counter_tft': 73}
# ---------------
# Generation number 28
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 3, 'counter_tft': 77}
# ---------------
# Generation number 29
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 3, 'counter_tft': 77}
# ---------------
# Generation number 30
# Number of individuals playing each strategy: {'destr': 0, 'coop1': 0, 'defect': 0, 'coop2': 0, 'tft': 0, 'detect': 0, 'forgiving_tft': 6, 'counter_tft': 74}
# ---------------

# %% [markdown]
# Podemos observar que funciona mucho mejor que el resto de estrategias en un torneo evolutivo contra todas, sin embargo esto puede deverse a que se aprovecha al inicio de estrategias simples para incrementar su poblacion. Por ello vmaos a enfrentarlo solo conra estrategias "buenas", siendo estas solo las TFT.

# %%
dilemma = Dilemma(13, 0, 18, 4)
participants = (Tft(dilemma, "tft"),
                Forgiving_TFT(dilemma,"forgiving_tft"),
                Counter_TFT(dilemma,"counter_tft"))

evolution = Evolution(participants, n_rounds=100, error=0.008, repetitions=2,
                      generations=10, reproductivity=0.3
                      ,
                      initial_population=(10, 10, 10))

evolution.play(True)
# Out:
# Initial number of individuals playing each strategy: {'tft': 10, 'forgiving_tft': 10, 'counter_tft': 10}
# ---------------
# Generation number 1
# Number of individuals playing each strategy: {'tft': 5, 'forgiving_tft': 6, 'counter_tft': 19}
# ---------------
# Generation number 2
# Number of individuals playing each strategy: {'tft': 1, 'forgiving_tft': 1, 'counter_tft': 28}
# ---------------
# Generation number 3
# Number of individuals playing each strategy: {'tft': 1, 'forgiving_tft': 1, 'counter_tft': 28}
# ---------------
# Generation number 4
# Number of individuals playing each strategy: {'tft': 2, 'forgiving_tft': 2, 'counter_tft': 26}
# ---------------
# Generation number 5
# Number of individuals playing each strategy: {'tft': 1, 'forgiving_tft': 1, 'counter_tft': 28}
# ---------------
# Generation number 6
# Number of individuals playing each strategy: {'tft': 1, 'forgiving_tft': 1, 'counter_tft': 28}
# ---------------
# Generation number 7
# Number of individuals playing each strategy: {'tft': 0, 'forgiving_tft': 0, 'counter_tft': 30}
# ---------------
# Generation number 8
# Number of individuals playing each strategy: {'tft': 0, 'forgiving_tft': 0, 'counter_tft': 30}
# ---------------
# Generation number 9
# Number of individuals playing each strategy: {'tft': 0, 'forgiving_tft': 0, 'counter_tft': 30}
# ---------------
# Generation number 10
# Number of individuals playing each strategy: {'tft': 0, 'forgiving_tft': 0, 'counter_tft': 30}
# ---------------

# %% [markdown]
# Vamos a recrear varias estrategias típicas y no tan típicas, que todo y no ser las definitivas que se van a presentar al torneo nos sirven para recrear nuestras simulaciones y además entender mejor el proceso evolutivo del torneo.

# %%
class Random(Player):

    def __init__(self, dilemma: Dilemma, name: str = "",prob_coportation = 0.5):
        """Cooperator"""
        self.prob_coportation = prob_coportation
        super().__init__(dilemma, name)


    def strategy(self, opponent: Player) -> int:
        """Cooperates always"""
        if random.random() <= self.prob_coportation:
            return C
        return D
    
class TwoTft(Player):

    def __init__(self, dilemma: Dilemma, name: str = ""):
        """Tit-for-tat"""
        super().__init__(dilemma, name)
        self.consecutive_defects = 0


    def strategy(self, opponent: Player) -> int:
        """Cooperates first, then repeat last action of the opponent"""
        
        if len(opponent.history) == 0:
            return C
        op_action = opponent.history[-1]
        if op_action==D:
            self.consecutive_defects +=1
        else:
            self.consecutive_defects = 0

        if self.consecutive_defects>=2:
            return D
        else:
            return C

class ForgivingGrudger(Grudger):
    def __init__(self, dilemma: Dilemma, name: str = "",rounds_to_forgive = 2):
        """Forgiving Grudger"""
        self.rounds_to_forgive = rounds_to_forgive
        self.counter_to_forgive = 0
        super().__init__(dilemma, name)


    def strategy(self, opponent: Player) -> int:
        """
        Cooperates always, but if opponent ever defects, it will defect for the
        rest of the game
        """
        
        if len(opponent.history)==0:
            return C
        elif self.beenBetrayed:
            if self.counter_to_forgive < self.rounds_to_forgive:
                self.counter_to_forgive += 1
                return D
            else:
                self.counter_to_forgive = 0
                self.beenBetrayed = False
                return C
        elif opponent.history[-1] == D:
            self.beenBetrayed = True
            return D
        return C
    
class PeriodicPatron(Player):
    def __init__(self, dilemma: Dilemma, name: str = "",patron:list = [C,D,C,D]):
        """Forgiving Grudger"""
        self.patron = patron
        self.counter = 0
        super().__init__(dilemma, name)

    def strategy(self, opponent:Player) -> int:
        action = self.patron[self.counter]
        self.counter= self.counter+1 if self.counter < len(self.patron)-1 else 0
        return action


class Win_stay_lose_shift(Player):
    def __init__(self, dilemma: Dilemma, name: str = ""):
        """win_stay_lose_shift"""
        super().__init__(dilemma, name)

    def strategy(self, opponent:Player) -> int:
        if len(opponent.history) == 0:
            return C
        if self.history[-1] == opponent.history[-1]:
            return C
        else:
            return D
        
class Gradual(Player):

    def __init__(self, dilemma: Dilemma, name: str = ""):
        """Gradual strategy"""
        super().__init__(dilemma, name)
        self.defect_count = 0  # Número de defecciones que ha hecho el oponente
        self.punishment_phase = 0  # Cuenta cuántas veces debe defectar
        self.coop_after_punishment = 0  # Cuenta las cooperaciones después del castigo

    def strategy(self, opponent: Player) -> int:
        """Decide next action based on opponent's defections"""
        
        # Cooperar en la primera ronda
        if len(self.history) == 0:
            return C
        
        # Si estamos en fase de castigo, defectar las veces necesarias
        if self.punishment_phase > 0:
            self.punishment_phase -= 1
            return D

        # Si estamos en fase de cooperaciones después del castigo, cooperar
        if self.coop_after_punishment > 0:
            self.coop_after_punishment -= 1
            return C
        
        # Contar cuántas veces ha defectado el oponente
        if opponent.history[-1] == D:
            self.defect_count += 1
            # Entrar en fase de castigo: defectar tantas veces como defecciones del oponente
            self.punishment_phase = self.defect_count
            self.coop_after_punishment = 2  # Después del castigo, cooperar 2 veces
        
        # Si no estamos en fase de castigo ni de cooperaciones, cooperar
        return C

# %% [markdown]
# Vamos a crear una estrategia que intente descubrir quien es nuestro oponente de manera iterativa, para asi poder aprovecharnos de la estrategia del oponente.
#
# Este proceso de descubrir quien es nuestro oponente lo hacemos viendo el resultado de las 2 ultimas jugadas.

# %%
class PerdonoPeroNoOlvido(Player):

    def __init__(self, dilemma: Dilemma, name: str = ""):
        super().__init__(dilemma, name)
        self.all_d_count = 0  # Contador de veces consecutivas que juega All-D
        self.last_two_moves = []  # Lista para almacenar las dos últimas interacciones

    def strategy(self, opponent: Player) -> int:
        
        # Si All-D ha sido jugado dos veces seguidas, continuar con All-D
        if self.all_d_count >= 2:
            return D  # Siempre defectar si ha elegido All-D dos veces

        # En las dos primeras rondas, cooperar (TFT en los primeros dos movimientos)
        if len(opponent.history) == 0:
            return C  # Cooperar en la primera ronda
        elif len(opponent.history) == 1:
            return opponent.history[-1]  # En la segunda ronda, copiar la acción del oponente

        # Almacenar las últimas dos interacciones
        self.last_two_moves = [(self.history[-2], opponent.history[-2]), (self.history[-1], opponent.history[-1])]

        # Calcular el payoff de las últimas dos interacciones
        payoff_last_two = self.calculate_payoff(self.last_two_moves)

        # Decidir la próxima acción según el payoff
        if payoff_last_two == 2 * self.dilemma.cc:
            # Si el payoff es 2CC (cooperación mutua dos veces), jugar TFT
            return opponent.history[-1]  # Copiar la última acción del oponente (TFT)
        elif payoff_last_two == self.dilemma.dc + self.dilemma.cd:
            # Si el payoff es DC+CD (una traición y una cooperación), jugar Two-Tits-for-Tat
            return self.two_tits_for_tat(opponent.history)
        else:
            # En cualquier otro caso, jugar All-D (siempre defectar)
            self.all_d_count += 1
            return D

    def calculate_payoff(self, last_two_moves) -> int:
        """Calcula el payoff basado en las últimas dos interacciones"""
        payoff = 0
        for my_action, opp_action in last_two_moves:
            if my_action == C and opp_action == C:
                payoff += self.dilemma.cc
            elif my_action == C and opp_action == D:
                payoff += self.dilemma.cd
            elif my_action == D and opp_action == C:
                payoff += self.dilemma.dc
            else:
                payoff += self.dilemma.dd
        return payoff

    def two_tits_for_tat(self, op_history: list) -> int:
        """Two-Tits-for-Tat: Defect if opponent defected in either of the last two rounds"""
        if op_history[-1] == D or op_history[-2] == D:
            return D
        return C

# %% [markdown]
# Finalmente vamos ha hacer un torneo evolutivo con todas estas estrategias. Para asegurarnos que la aparente mejor estrategia no gana por suerte, vamos a realizarlo 3 veces

# %%
# List All players
all_participants = (
Destructomatic(dilemma, "destruc"),
Cooperator(dilemma, "al_coop"),
Defector(dilemma, "al_defect"),
Tft(dilemma, "tft"),
Forgiving_TFT(dilemma,"forgiving_tft"),
Grudger(dilemma, "grudger"),
Detective4MovsTft(dilemma, "detective"),
Counter_TFT(dilemma, "counter_tft"),
Random(dilemma, "random05", 0.5),
Random(dilemma, "random01", 0.75),
TwoTft(dilemma, "two_tft"),
ForgivingGrudger(dilemma, "forgiving_grudger2",2),
PeriodicPatron(dilemma, "periodic_CDCD", [C,D,C,D]),
PeriodicPatron(dilemma, "periodic_CDD", [C,D,D]),
Gradual(dilemma, "gradual"),
PerdonoPeroNoOlvido(dilemma, "PerdonoPeroNoOlvido"),
Win_stay_lose_shift(dilemma, "win_stay_lose_shift")
)

# %% [markdown]
# Primer torneo

# %%
dilemma = Dilemma(13, 0, 18, 4)
participants = all_participants
initial_population = tuple([10 for _ in range(len(participants))])

evolution = Evolution(participants, n_rounds=100, error=0.008, repetitions=2,
                      generations=30, reproductivity=0.05,
                      initial_population=initial_population)

evolution.play(True)
# Out:
# Initial number of individuals playing each strategy: {'destruc': 10, 'al_coop': 10, 'al_defect': 10, 'tft': 10, 'forgiving_tft': 10, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 10, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 10, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 1
# Number of individuals playing each strategy: {'destruc': 6, 'al_coop': 10, 'al_defect': 10, 'tft': 13, 'forgiving_tft': 15, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 6, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 10, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 2
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 9, 'tft': 17, 'forgiving_tft': 19, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 5, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 10, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 3
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 6, 'tft': 20, 'forgiving_tft': 24, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 5, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 5, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 4
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 1, 'tft': 26, 'forgiving_tft': 26, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 5, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 2, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 5
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 28, 'forgiving_tft': 32, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 5, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 5, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 6
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 31, 'forgiving_tft': 37, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 5, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 7, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 7
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 34, 'forgiving_tft': 41, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 6, 'random01': 5, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 3, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 11}
# ---------------
# Generation number 8
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 37, 'forgiving_tft': 46, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 1, 'random01': 5, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 11}
# ---------------
# Generation number 9
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 47, 'grudger': 3, 'detective': 10, 'counter_tft': 11, 'random05': 0, 'random01': 5, 'two_tft': 13, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 12}
# ---------------
# Generation number 10
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 47, 'grudger': 0, 'detective': 8, 'counter_tft': 19, 'random05': 0, 'random01': 3, 'two_tft': 13, 'forgiving_grudger2': 10, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 12}
# ---------------
# Generation number 11
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 47, 'grudger': 0, 'detective': 2, 'counter_tft': 21, 'random05': 0, 'random01': 2, 'two_tft': 13, 'forgiving_grudger2': 10, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 17}
# ---------------
# Generation number 12
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 9, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 47, 'grudger': 0, 'detective': 0, 'counter_tft': 26, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 10, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 16}
# ---------------
# Generation number 13
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 8, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 49, 'grudger': 0, 'detective': 0, 'counter_tft': 31, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 9, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 11}
# ---------------
# Generation number 14
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 8, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 49, 'grudger': 0, 'detective': 0, 'counter_tft': 35, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 9, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 7}
# ---------------
# Generation number 15
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 8, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 49, 'grudger': 0, 'detective': 0, 'counter_tft': 38, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 9, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 4}
# ---------------
# Generation number 16
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 6, 'al_defect': 0, 'tft': 40, 'forgiving_tft': 49, 'grudger': 0, 'detective': 0, 'counter_tft': 37, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 9, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 6}
# ---------------
# Generation number 17
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 6, 'al_defect': 0, 'tft': 40, 'forgiving_tft': 49, 'grudger': 0, 'detective': 0, 'counter_tft': 40, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 9, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 3}
# ---------------
# Generation number 18
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 6, 'al_defect': 0, 'tft': 40, 'forgiving_tft': 49, 'grudger': 0, 'detective': 0, 'counter_tft': 41, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 9, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 19
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 1, 'al_defect': 0, 'tft': 41, 'forgiving_tft': 55, 'grudger': 0, 'detective': 0, 'counter_tft': 39, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 9, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 20
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 1, 'al_defect': 0, 'tft': 45, 'forgiving_tft': 59, 'grudger': 0, 'detective': 0, 'counter_tft': 33, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 9, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 21
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 1, 'al_defect': 0, 'tft': 45, 'forgiving_tft': 59, 'grudger': 0, 'detective': 0, 'counter_tft': 33, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 9, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 22
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 1, 'al_defect': 0, 'tft': 45, 'forgiving_tft': 59, 'grudger': 0, 'detective': 0, 'counter_tft': 38, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 4, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 23
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 45, 'forgiving_tft': 60, 'grudger': 0, 'detective': 0, 'counter_tft': 42, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 0, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 24
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 45, 'forgiving_tft': 60, 'grudger': 0, 'detective': 0, 'counter_tft': 42, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 0, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 25
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 45, 'forgiving_tft': 60, 'grudger': 0, 'detective': 0, 'counter_tft': 42, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 0, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 26
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 48, 'forgiving_tft': 65, 'grudger': 0, 'detective': 0, 'counter_tft': 34, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 0, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 27
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 49, 'forgiving_tft': 67, 'grudger': 0, 'detective': 0, 'counter_tft': 26, 'random05': 0, 'random01': 0, 'two_tft': 19, 'forgiving_grudger2': 0, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 28
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 49, 'forgiving_tft': 67, 'grudger': 0, 'detective': 0, 'counter_tft': 18, 'random05': 0, 'random01': 0, 'two_tft': 27, 'forgiving_grudger2': 0, 'periodic_CDCD': 9, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 29
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 49, 'forgiving_tft': 67, 'grudger': 0, 'detective': 0, 'counter_tft': 18, 'random05': 0, 'random01': 0, 'two_tft': 35, 'forgiving_grudger2': 0, 'periodic_CDCD': 1, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 30
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 49, 'forgiving_tft': 67, 'grudger': 0, 'detective': 0, 'counter_tft': 10, 'random05': 0, 'random01': 0, 'two_tft': 43, 'forgiving_grudger2': 0, 'periodic_CDCD': 1, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------

# %% [markdown]
# Segundo torneo

# %%
dilemma = Dilemma(13, 0, 18, 4)
participants = all_participants
initial_population = tuple([10 for _ in range(len(participants))])

evolution = Evolution(participants, n_rounds=100, error=0.008, repetitions=2,
                      generations=30, reproductivity=0.05,
                      initial_population=initial_population)

evolution.play(True)
# Out:
# Initial number of individuals playing each strategy: {'destruc': 10, 'al_coop': 10, 'al_defect': 10, 'tft': 10, 'forgiving_tft': 10, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 10, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 10, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 1
# Number of individuals playing each strategy: {'destruc': 8, 'al_coop': 10, 'al_defect': 10, 'tft': 13, 'forgiving_tft': 15, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 4, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 10, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 2
# Number of individuals playing each strategy: {'destruc': 1, 'al_coop': 10, 'al_defect': 10, 'tft': 15, 'forgiving_tft': 21, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 3, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 10, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 3
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 7, 'tft': 18, 'forgiving_tft': 26, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 3, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 6, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 4
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 2, 'tft': 21, 'forgiving_tft': 31, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 3, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 3, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 5
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 23, 'forgiving_tft': 37, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 3, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 7, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 6
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 27, 'forgiving_tft': 40, 'grudger': 10, 'detective': 10, 'counter_tft': 11, 'random05': 9, 'random01': 3, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 7
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 30, 'forgiving_tft': 45, 'grudger': 10, 'detective': 10, 'counter_tft': 11, 'random05': 7, 'random01': 3, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 4, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 8
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 33, 'forgiving_tft': 50, 'grudger': 9, 'detective': 10, 'counter_tft': 11, 'random05': 4, 'random01': 3, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 9
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 33, 'forgiving_tft': 56, 'grudger': 5, 'detective': 10, 'counter_tft': 13, 'random05': 0, 'random01': 3, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 10
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 35, 'forgiving_tft': 56, 'grudger': 0, 'detective': 7, 'counter_tft': 18, 'random05': 0, 'random01': 3, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 11}
# ---------------
# Generation number 11
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 9, 'al_defect': 0, 'tft': 35, 'forgiving_tft': 56, 'grudger': 0, 'detective': 3, 'counter_tft': 26, 'random05': 0, 'random01': 3, 'two_tft': 10, 'forgiving_grudger2': 7, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 11}
# ---------------
# Generation number 12
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 9, 'al_defect': 0, 'tft': 35, 'forgiving_tft': 56, 'grudger': 0, 'detective': 0, 'counter_tft': 33, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 6, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 11}
# ---------------
# Generation number 13
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 3, 'al_defect': 0, 'tft': 35, 'forgiving_tft': 56, 'grudger': 0, 'detective': 0, 'counter_tft': 41, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 6, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 9}
# ---------------
# Generation number 14
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 35, 'forgiving_tft': 56, 'grudger': 0, 'detective': 0, 'counter_tft': 46, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 6, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 7}
# ---------------
# Generation number 15
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 35, 'forgiving_tft': 56, 'grudger': 0, 'detective': 0, 'counter_tft': 47, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 6, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 6}
# ---------------
# Generation number 16
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 36, 'forgiving_tft': 61, 'grudger': 0, 'detective': 0, 'counter_tft': 41, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 6, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 6}
# ---------------
# Generation number 17
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 64, 'grudger': 0, 'detective': 0, 'counter_tft': 38, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 6, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 3}
# ---------------
# Generation number 18
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 65, 'grudger': 0, 'detective': 0, 'counter_tft': 38, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 5, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 3}
# ---------------
# Generation number 19
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 65, 'grudger': 0, 'detective': 0, 'counter_tft': 44, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 0, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 20
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 65, 'grudger': 0, 'detective': 0, 'counter_tft': 44, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 0, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 21
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 44, 'forgiving_tft': 68, 'grudger': 0, 'detective': 0, 'counter_tft': 36, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 0, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 22
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 45, 'forgiving_tft': 75, 'grudger': 0, 'detective': 0, 'counter_tft': 28, 'random05': 0, 'random01': 0, 'two_tft': 10, 'forgiving_grudger2': 0, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 23
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 47, 'forgiving_tft': 76, 'grudger': 0, 'detective': 0, 'counter_tft': 23, 'random05': 0, 'random01': 0, 'two_tft': 15, 'forgiving_grudger2': 0, 'periodic_CDCD': 7, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 24
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 47, 'forgiving_tft': 76, 'grudger': 0, 'detective': 0, 'counter_tft': 27, 'random05': 0, 'random01': 0, 'two_tft': 19, 'forgiving_grudger2': 0, 'periodic_CDCD': 0, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 1}
# ---------------
# Generation number 25
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 47, 'forgiving_tft': 76, 'grudger': 0, 'detective': 0, 'counter_tft': 23, 'random05': 0, 'random01': 0, 'two_tft': 23, 'forgiving_grudger2': 0, 'periodic_CDCD': 0, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 1}
# ---------------
# Generation number 26
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 46, 'forgiving_tft': 74, 'grudger': 0, 'detective': 0, 'counter_tft': 19, 'random05': 0, 'random01': 0, 'two_tft': 31, 'forgiving_grudger2': 0, 'periodic_CDCD': 0, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 27
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 46, 'forgiving_tft': 74, 'grudger': 0, 'detective': 0, 'counter_tft': 11, 'random05': 0, 'random01': 0, 'two_tft': 39, 'forgiving_grudger2': 0, 'periodic_CDCD': 0, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 28
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 46, 'forgiving_tft': 74, 'grudger': 0, 'detective': 0, 'counter_tft': 3, 'random05': 0, 'random01': 0, 'two_tft': 47, 'forgiving_grudger2': 0, 'periodic_CDCD': 0, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 29
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 44, 'forgiving_tft': 71, 'grudger': 0, 'detective': 0, 'counter_tft': 0, 'random05': 0, 'random01': 0, 'two_tft': 55, 'forgiving_grudger2': 0, 'periodic_CDCD': 0, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 30
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 44, 'forgiving_tft': 63, 'grudger': 0, 'detective': 0, 'counter_tft': 0, 'random05': 0, 'random01': 0, 'two_tft': 63, 'forgiving_grudger2': 0, 'periodic_CDCD': 0, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------

# %% [markdown]
# Tercer torneo

# %%
dilemma = Dilemma(13, 0, 18, 4)
participants = all_participants
initial_population = tuple([10 for _ in range(len(participants))])

evolution = Evolution(participants, n_rounds=100, error=0.008, repetitions=2,
                      generations=30, reproductivity=0.05,
                      initial_population=initial_population)

evolution.play(True)
# Out:
# Initial number of individuals playing each strategy: {'destruc': 10, 'al_coop': 10, 'al_defect': 10, 'tft': 10, 'forgiving_tft': 10, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 10, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 10, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 1
# Number of individuals playing each strategy: {'destruc': 7, 'al_coop': 10, 'al_defect': 10, 'tft': 15, 'forgiving_tft': 13, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 5, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 10, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 2
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 10, 'tft': 19, 'forgiving_tft': 17, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 4, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 10, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 3
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 4, 'tft': 24, 'forgiving_tft': 20, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 4, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 8, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 4
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 1, 'tft': 29, 'forgiving_tft': 23, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 4, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 10, 'PerdonoPeroNoOlvido': 3, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 5
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 34, 'forgiving_tft': 26, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 10, 'random01': 4, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 6, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 6
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 39, 'forgiving_tft': 29, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 8, 'random01': 4, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 10, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 7
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 42, 'forgiving_tft': 34, 'grudger': 10, 'detective': 10, 'counter_tft': 10, 'random05': 5, 'random01': 4, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 5, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 8
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 46, 'forgiving_tft': 37, 'grudger': 10, 'detective': 10, 'counter_tft': 11, 'random05': 2, 'random01': 4, 'two_tft': 10, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 10}
# ---------------
# Generation number 9
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 46, 'forgiving_tft': 39, 'grudger': 4, 'detective': 10, 'counter_tft': 13, 'random05': 0, 'random01': 4, 'two_tft': 13, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 11}
# ---------------
# Generation number 10
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 10, 'al_defect': 0, 'tft': 46, 'forgiving_tft': 39, 'grudger': 0, 'detective': 8, 'counter_tft': 20, 'random05': 0, 'random01': 2, 'two_tft': 13, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 12}
# ---------------
# Generation number 11
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 8, 'al_defect': 0, 'tft': 46, 'forgiving_tft': 39, 'grudger': 0, 'detective': 4, 'counter_tft': 28, 'random05': 0, 'random01': 1, 'two_tft': 13, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 11}
# ---------------
# Generation number 12
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 7, 'al_defect': 0, 'tft': 46, 'forgiving_tft': 39, 'grudger': 0, 'detective': 1, 'counter_tft': 31, 'random05': 0, 'random01': 1, 'two_tft': 13, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 12}
# ---------------
# Generation number 13
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 4, 'al_defect': 0, 'tft': 50, 'forgiving_tft': 40, 'grudger': 0, 'detective': 1, 'counter_tft': 30, 'random05': 0, 'random01': 1, 'two_tft': 13, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 11}
# ---------------
# Generation number 14
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 4, 'al_defect': 0, 'tft': 52, 'forgiving_tft': 41, 'grudger': 0, 'detective': 0, 'counter_tft': 30, 'random05': 0, 'random01': 1, 'two_tft': 13, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 9}
# ---------------
# Generation number 15
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 4, 'al_defect': 0, 'tft': 52, 'forgiving_tft': 41, 'grudger': 0, 'detective': 0, 'counter_tft': 35, 'random05': 0, 'random01': 0, 'two_tft': 13, 'forgiving_grudger2': 10, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 5}
# ---------------
# Generation number 16
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 3, 'al_defect': 0, 'tft': 52, 'forgiving_tft': 41, 'grudger': 0, 'detective': 0, 'counter_tft': 37, 'random05': 0, 'random01': 0, 'two_tft': 13, 'forgiving_grudger2': 9, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 5}
# ---------------
# Generation number 17
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 2, 'al_defect': 0, 'tft': 52, 'forgiving_tft': 41, 'grudger': 0, 'detective': 0, 'counter_tft': 39, 'random05': 0, 'random01': 0, 'two_tft': 13, 'forgiving_grudger2': 9, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 4}
# ---------------
# Generation number 18
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 2, 'al_defect': 0, 'tft': 52, 'forgiving_tft': 42, 'grudger': 0, 'detective': 0, 'counter_tft': 39, 'random05': 0, 'random01': 0, 'two_tft': 13, 'forgiving_grudger2': 9, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 3}
# ---------------
# Generation number 19
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 2, 'al_defect': 0, 'tft': 52, 'forgiving_tft': 42, 'grudger': 0, 'detective': 0, 'counter_tft': 40, 'random05': 0, 'random01': 0, 'two_tft': 13, 'forgiving_grudger2': 9, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 20
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 2, 'al_defect': 0, 'tft': 52, 'forgiving_tft': 42, 'grudger': 0, 'detective': 0, 'counter_tft': 40, 'random05': 0, 'random01': 0, 'two_tft': 13, 'forgiving_grudger2': 9, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 21
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 1, 'al_defect': 0, 'tft': 57, 'forgiving_tft': 44, 'grudger': 0, 'detective': 0, 'counter_tft': 33, 'random05': 0, 'random01': 0, 'two_tft': 13, 'forgiving_grudger2': 9, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 3}
# ---------------
# Generation number 22
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 1, 'al_defect': 0, 'tft': 60, 'forgiving_tft': 45, 'grudger': 0, 'detective': 0, 'counter_tft': 31, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 5, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 4}
# ---------------
# Generation number 23
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 1, 'al_defect': 0, 'tft': 60, 'forgiving_tft': 45, 'grudger': 0, 'detective': 0, 'counter_tft': 37, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 0, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 3}
# ---------------
# Generation number 24
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 1, 'al_defect': 0, 'tft': 60, 'forgiving_tft': 45, 'grudger': 0, 'detective': 0, 'counter_tft': 37, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 0, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 3}
# ---------------
# Generation number 25
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 66, 'forgiving_tft': 46, 'grudger': 0, 'detective': 0, 'counter_tft': 30, 'random05': 0, 'random01': 0, 'two_tft': 14, 'forgiving_grudger2': 0, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 4}
# ---------------
# Generation number 26
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 67, 'forgiving_tft': 46, 'grudger': 0, 'detective': 0, 'counter_tft': 24, 'random05': 0, 'random01': 0, 'two_tft': 21, 'forgiving_grudger2': 0, 'periodic_CDCD': 10, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 27
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 69, 'forgiving_tft': 46, 'grudger': 0, 'detective': 0, 'counter_tft': 25, 'random05': 0, 'random01': 0, 'two_tft': 26, 'forgiving_grudger2': 0, 'periodic_CDCD': 2, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 2}
# ---------------
# Generation number 28
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 70, 'forgiving_tft': 46, 'grudger': 0, 'detective': 0, 'counter_tft': 24, 'random05': 0, 'random01': 0, 'two_tft': 29, 'forgiving_grudger2': 0, 'periodic_CDCD': 0, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 1}
# ---------------
# Generation number 29
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 69, 'forgiving_tft': 46, 'grudger': 0, 'detective': 0, 'counter_tft': 18, 'random05': 0, 'random01': 0, 'two_tft': 37, 'forgiving_grudger2': 0, 'periodic_CDCD': 0, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------
# Generation number 30
# Number of individuals playing each strategy: {'destruc': 0, 'al_coop': 0, 'al_defect': 0, 'tft': 69, 'forgiving_tft': 46, 'grudger': 0, 'detective': 0, 'counter_tft': 10, 'random05': 0, 'random01': 0, 'two_tft': 45, 'forgiving_grudger2': 0, 'periodic_CDCD': 0, 'periodic_CDD': 0, 'gradual': 0, 'PerdonoPeroNoOlvido': 0, 'win_stay_lose_shift': 0}
# ---------------

# %% [markdown]
# Podemos observar como la mejor estrategia no existe debido a que gran parte del exito depende de como afecte la probabilidad de error a los algoritmos, lo cual afectara a que algoritmos sobrevivan en la poblacion.
#
# Por ello hemos optar por la estrategia de Counter_TFT, la cual ha sobrevivido con una alta población en bastantes casos.

# %%
class Counter_TFT(Player):

    def __init__(self, dilemma: Dilemma, name: str = "",error_prob = 0.008):
        super().__init__(dilemma, name)

        self.error_prob = error_prob
        self.FIRST_MOVES = [D,C,D,C]
        
        self.simple_strategy = []
        

    def strategy(self, opponent: Player) -> int:
        """
        Podemos intentar averiguar las estrategias de los oponentes para saber si perdonan o no y aprovecharnos de eso.
        Por ello si perdonan las no cooperaciones, de vez en cuando no cooperamos. 
        Si no perdonan pero se acaban cooperando siempre cooperamos (ya que al final acabaremos ganando mas puntos aunque el oponente tambien) 
        Sin embargo si no responden a nuestra estrategia nos aprovechamos de ella (si coopera cooperamos sino no cooperamos).
        """

        # Realizamos los movimientos predeterminados
        if len(self.history) < len(self.FIRST_MOVES):
            return self.FIRST_MOVES[len(self.history)]

        # Observamos el historial para analizar al rival. Dado que la probabilidad de error es muy baja vamos a suponer que aun no se han equivocado
        if len(self.history) == len(self.FIRST_MOVES):
            # Vemos si es un tft
            if opponent.history[2] == C and opponent.history[3] == D:
                # vemos si perdono la primera no cooperacion
                if opponent.history[1] == D:
                    # Es un tft
                    # Nuestra estrategia va a ser siempre cooperar ya que sabemos que tft acabara cooperando tambien, maximizando nuestros puntos
                    self.simple_strategy = [C] 
                
                # si nos perdono solo la primera vez
                else:
                    # Es una implementacion que perdona
                    # Nuestra estrategia va a ser siempre cooperar hasta que llevemos por ejemplo 1/prob_error rondas cooperando, donde no
                    # cooperamos porque es muy probable que nos perdone

                    self.simple_strategy = ([C]* int(1/self.error_prob)) + [D]
            
            # Si parece que no se ha reaccionado a nuestros movimientos, suponiendo que no se ha equivocado 
            else:
                # si siempre ha cooperado
                if opponent.history[0] == C and opponent.history[1] == C and opponent.history[2] == C and \
                    opponent.history[3] == C:

                    # Es un algoritmo que coopera siempre, nos aprovechamos de el nunca cooperando
                    self.simple_strategy = [D]
                
                # si tras la no cooperacion no ha cooperado, podemos suponer que nunca lo hara
                if opponent.history[1] == D and opponent.history[2] == D and \
                    opponent.history[3] == D:

                    # por tanto no cooperamos
                    self.simple_strategy = [D]


        # Si hemos encontrado una estrategia buena, realizamos la estrategia ya programada en base al oponente
        if len(self.simple_strategy) > 0:
            return self.simple_strategy[len(opponent.history)%len(self.simple_strategy)]
        
        # Si no hemmos encontrado una estrategia buena, hacemos un tft
        else:
            return opponent.history[-1]

# %%
Counter_TFT(dilemma, "counter_tft")

# %% [markdown]
# ## Rúbrica de calificación de la práctica
#
# PARTE 1:
#  - **[4/10] Funcionamiento del código**: el código descrito en la *Parte 1* de la práctica debe funcionar correctamente, sin *bugs*, permitiendo reproducir todas las funcionalidades descritas.
#  - **[2/10] Limpieza y claridad de estilo**: el código debe estar bien escrito, siguiendo la guía de estilo PEP 8.
#
# PARTE 2:
#  - **[1/10] Implementación de una estrategia correcta**: que funcione sin errores y que esté programada con claridad.
#  - **[3/10] Originalidad de la estrategia y trabajo de exploración llevado a cabo**: el tipo de estrategia presentada, junto con las explicaciones que hayas aportado en comentarios y demás, pondrá de manifiesto el trabajo de experimentación que has llevado a cabo con tu estrategia. Este item pretende evaluar este aspecto.
#
# EXTRAS:
#  - **[1.5 puntos] extras al ganador del campeonato**
